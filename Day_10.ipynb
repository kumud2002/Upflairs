# %% [markdown]
# ## Day - 10 \\ 26-04-2023

# %% [markdown]
# Image Processing and Computer Vision
# - Image Procesing - Image is a function of light.
# - Data stored in 8 bit unsigned.

# %% [markdown]
# Image types (Color Standards) -
# + True Color(RGB)
# + Grayscale
# + Binary

# %%
import cv2 as cv
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv.imread(r'C:\Users\Kumud Jain\OneDrive\Desktop\Upflairs\Stuff\download.jpeg')
cv.imshow('Title',img)
cv.waitKey(0)
# Out:
# -1

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
img1 = plt.imread(r'C:\Users\Kumud Jain\OneDrive\Desktop\Upflairs\Stuff\download.jpeg')
plt.imshow(img)
